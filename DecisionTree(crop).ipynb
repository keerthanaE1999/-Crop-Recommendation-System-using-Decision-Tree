# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import classification_report,accuracy_score

# %%
df=pd.read_csv("Crop_Recommendation (1).csv")

# %%
df
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         Rainfall    Crop
# 0     202.935536    Rice
# 1     226.655537    Rice
# 2     263.964248    Rice
# 3     242.864034    Rice
# 4     262.717340    Rice
# ...          ...     ...
# 2195  177.774507  Coffee
# 2196  127.924610  Coffee
# 2197  173.322839  Coffee
# 2198  127.175293  Coffee
# 2199  140.937041  Coffee
#
# [2200 rows x 8 columns]

# %%
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]

# %%
# Out:
# 0         Rice
# 1         Rice
# 2         Rice
# 3         Rice
# 4         Rice
#          ...
# 2195    Coffee
# 2196    Coffee
# 2197    Coffee
# 2198    Coffee
# 2199    Coffee
# Name: Crop, Length: 2200, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.20,random_state=42,stratify=Y)

# %%
model=DecisionTreeClassifier(criterion='entropy',max_depth=6,min_samples_split=10,min_samples_leaf=5,random_state=42)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, min_samples_leaf=5,
#                        min_samples_split=10, random_state=42)

# %%
model.predict(x_test)
# Out:
# array(['Orange', 'Banana', 'Cotton', 'Maize', 'Orange', 'ChickPea',
#        'Rice', 'Blackgram', 'Banana', 'Orange', 'Watermelon',
#        'Pomegranate', 'Watermelon', 'Maize', 'MothBeans', 'Grapes',
#        'Grapes', 'Mango', 'Mango', 'Apple', 'Blackgram', 'Apple',
#        'MothBeans', 'KidneyBeans', 'Apple', 'Jute', 'MothBeans',
#        'Watermelon', 'Rice', 'Coffee', 'Mango', 'Jute', 'Banana',
#        'Coffee', 'Jute', 'Blackgram', 'Grapes', 'Grapes', 'Blackgram',
#        'Jute', 'Coconut', 'Papaya', 'Mango', 'Maize', 'Lentil', 'Jute',
#        'Cotton', 'Lentil', 'ChickPea', 'MungBean', 'Papaya',
#        'Pomegranate', 'Mango', 'Watermelon', 'Mango', 'MothBeans',
#        'Papaya', 'Papaya', 'Coffee', 'Lentil', 'Lentil', 'MothBeans',
#        'Coffee', 'Banana', 'Papaya', 'Rice', 'Orange', 'Coconut',
#        'MothBeans', 'Pomegranate', 'Banana', 'Muskmelon', 'Watermelon',
#        'Lentil', 'Banana', 'Coconut', 'MothBeans', 'MungBean', 'MungBean',
#        'Mango', 'Coffee', 'Watermelon', 'Muskmelon', 'KidneyBeans',
#        'Mango', 'Pomegranate', 'Orange', 'Cotton', 'Coconut', 'Papaya',
#        'MothBeans', 'MungBean', 'MothBeans', 'Cotton', 'Jute', 'Grapes',
#        'Cotton', 'ChickPea', 'Jute', 'Watermelon', 'Muskmelon',
#        'Pomegranate', 'Orange', 'PigeonPeas', 'PigeonPeas', 'Grapes',
#        'KidneyBeans', 'Lentil', 'Rice', 'Rice', 'Apple', 'MungBean',
#        'MungBean', 'Grapes', 'Rice', 'Muskmelon', 'Blackgram', 'Lentil',
#        'Banana', 'Orange', 'Orange', 'ChickPea', 'Maize', 'Mango',
#        'Cotton', 'Lentil', 'Banana', 'Pomegranate', 'Coconut', 'MungBean',
#        'Cotton', 'ChickPea', 'Jute', 'MungBean', 'MothBeans', 'Maize',
#        'Apple', 'ChickPea', 'Rice', 'Cotton', 'Cotton', 'Jute',
#        'Pomegranate', 'Mango', 'Jute', 'Papaya', 'Banana', 'Orange',
#        'PigeonPeas', 'Lentil', 'Maize', 'ChickPea', 'Cotton',
#        'Watermelon', 'MothBeans', 'Maize', 'PigeonPeas', 'Muskmelon',
#        'Apple', 'MungBean', 'Blackgram', 'ChickPea', 'Maize', 'Maize',
#        'KidneyBeans', 'Coffee', 'Orange', 'Maize', 'Grapes',
#        'Pomegranate', 'Apple', 'Coconut', 'Muskmelon', 'Grapes', 'Cotton',
#        'Lentil', 'PigeonPeas', 'ChickPea', 'Maize', 'MothBeans', 'Apple',
#        'Muskmelon', 'Cotton', 'Watermelon', 'Muskmelon', 'Watermelon',
#        'Orange', 'Watermelon', 'Coffee', 'KidneyBeans', 'Apple',
#        'ChickPea', 'Blackgram', 'Coffee', 'Muskmelon', 'Coffee', 'Apple',
#        'Grapes', 'Jute', 'Papaya', 'Coconut', 'Grapes', 'Watermelon',
#        'MungBean', 'Pomegranate', 'PigeonPeas', 'MungBean', 'Lentil',
#        'Apple', 'Muskmelon', 'ChickPea', 'Apple', 'Cotton', 'ChickPea',
#        'Banana', 'Pomegranate', 'Pomegranate', 'Maize', 'Orange', 'Jute',
#        'Cotton', 'Cotton', 'Maize', 'Grapes', 'MungBean', 'Lentil',
#        'PigeonPeas', 'Papaya', 'MungBean', 'Apple', 'Banana', 'Rice',
#        'ChickPea', 'Maize', 'Rice', 'Orange', 'Blackgram', 'Coconut',
#        'Rice', 'Grapes', 'KidneyBeans', 'Cotton', 'MungBean', 'MungBean',
#        'Coconut', 'Apple', 'Lentil', 'Papaya', 'Pomegranate', 'ChickPea',
#        'Blackgram', 'KidneyBeans', 'PigeonPeas', 'Jute', 'Muskmelon',
#        'Pomegranate', 'Blackgram', 'ChickPea', 'Muskmelon', 'Mango',
#        'ChickPea', 'Watermelon', 'ChickPea', 'Pomegranate', 'Mango',
#        'MothBeans', 'Cotton', 'Jute', 'Apple', 'KidneyBeans', 'Coconut',
#        'Papaya', 'Coffee', 'Blackgram', 'Coconut', 'Coconut', 'Blackgram',
#        'Lentil', 'KidneyBeans', 'MungBean', 'Coffee', 'Cotton', 'Grapes',
#        'Coffee', 'MothBeans', 'MothBeans', 'Lentil', 'Watermelon',
#        'Pomegranate', 'Apple', 'Orange', 'Mango', 'Jute', 'Banana',
#        'Lentil', 'MungBean', 'Blackgram', 'MothBeans', 'Watermelon',
#        'PigeonPeas', 'Lentil', 'Banana', 'Apple', 'Banana', 'Watermelon',
#        'Blackgram', 'Blackgram', 'Rice', 'Papaya', 'Banana',
#        'KidneyBeans', 'Banana', 'Muskmelon', 'Muskmelon', 'Orange',
#        'Cotton', 'Banana', 'PigeonPeas', 'Jute', 'Apple', 'Lentil',
#        'Muskmelon', 'Coconut', 'Papaya', 'Jute', 'Cotton', 'Orange',
#        'Orange', 'Blackgram', 'Mango', 'Mango', 'Muskmelon', 'Jute',
#        'Muskmelon', 'Papaya', 'Mango', 'ChickPea', 'PigeonPeas',
#        'Pomegranate', 'Watermelon', 'Rice', 'MungBean', 'Watermelon',
#        'Apple', 'Rice', 'Banana', 'Jute', 'Blackgram', 'PigeonPeas',
#        'MungBean', 'MothBeans', 'KidneyBeans', 'MothBeans', 'Rice',
#        'Blackgram', 'Coffee', 'Coffee', 'Grapes', 'Pomegranate',
#        'Pomegranate', 'PigeonPeas', 'Pomegranate', 'Mango', 'Coconut',
#        'PigeonPeas', 'MothBeans', 'Cotton', 'Cotton', 'Banana', 'Jute',
#        'Watermelon', 'Muskmelon', 'KidneyBeans', 'Blackgram', 'Coffee',
#        'PigeonPeas', 'MungBean', 'ChickPea', 'Jute', 'Grapes',
#        'Muskmelon', 'Cotton', 'Mango', 'Blackgram', 'ChickPea', 'Cotton',
#        'Maize', 'Papaya', 'MothBeans', 'KidneyBeans', 'PigeonPeas',
#        'Pomegranate', 'Coffee', 'Blackgram', 'Lentil', 'Muskmelon',
#        'MothBeans', 'Papaya', 'Rice', 'PigeonPeas', 'Grapes', 'Blackgram',
#        'Mango', 'Coffee', 'Orange', 'Coconut', 'Rice', 'KidneyBeans',
#        'Papaya', 'Coffee', 'Watermelon', 'MothBeans', 'Apple', 'Lentil',
#        'Papaya', 'Coconut', 'Papaya', 'Coffee', 'Coconut', 'Jute',
#        'Coconut', 'Coffee', 'Rice', 'Orange', 'Mango', 'Orange',
#        'Coconut', 'Coconut', 'Grapes', 'Cotton', 'Banana', 'Grapes',
#        'Mango', 'Mango', 'MothBeans', 'Cotton', 'Apple', 'Jute', 'Grapes',
#        'Mango'], dtype=object)

# %%
plt.figure(figsize=(30,30))
plot_tree(model, feature_names=X.columns, class_names=model.classes_, filled=True)
plt.show()
